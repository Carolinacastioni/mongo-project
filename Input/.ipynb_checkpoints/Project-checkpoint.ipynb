# %% [markdown]
# ## Import all the libraries

# %%
from pymongo import MongoClient
import re
from pymongo import ASCENDING, DESCENDING
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
import requests

# %% [markdown]
# ## Import the dataset Companies

# %%
dbName = "datamad0320"
mongodbURL = f"mongodb://localhost/{dbName}"
print(mongodbURL)
client = MongoClient(mongodbURL, connectTimeoutMS=2000,serverSelectionTimeoutMS=2000)
db = client.get_database()
# Out:
# mongodb://localhost/datamad0320

# %% [markdown]
# # First Analysis: Decide the City

# %% [markdown]
# ## What is the city with more Gaming companies?

# %% [markdown]
# This could be interresting to see where to install the new office of our Gaming company.

# %% [markdown]
# ## Get all the offices with category Gaming

# %%
a = list(db.companies.aggregate([{"$unwind":"$offices"},{"$project":{"offices":1,"name":1,"category_code":1}}]))

# %%
df = pd.DataFrame(json_normalize(a))
print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
# (16705, 12)
#                         _id       name    category_code offices.description  \
# 0  52cdef7c4bab8bd675297d8a   Wetpaint              web
# 1  52cdef7c4bab8bd675297d8a   Wetpaint              web
# 2  52cdef7c4bab8bd675297d8b  AdventNet       enterprise        Headquarters
# 3  52cdef7c4bab8bd675297d8c       Zoho         software        Headquarters
# 4  52cdef7c4bab8bd675297d8f  Omnidrive  network_hosting
#
#        offices.address1 offices.address2 offices.zip_code offices.city  \
# 0      710 - 2nd Avenue       Suite 1100            98104      Seattle
# 1  270 Lafayette Street        Suite 505            10012     New York
# 2      4900 Hopyard Rd.        Suite 310            94588   Pleasanton
# 3       4900 Hopyard Rd        Suite 310            94588   Pleasanton
# 4             Suite 200  654 High Street            94301    Palo Alto
#
#   offices.state_code offices.country_code  offices.latitude  offices.longitude
# 0                 WA                  USA         47.603122        -122.333253
# 1                 NY                  USA         40.723731         -73.996431
# 2                 CA                  USA         37.692934        -121.904945
# 3                 CA                  USA         37.692934        -121.904945
# 4                 CA                  ISR               NaN                NaN

# %% [markdown]
# ## Filter only Category Gaming that has the city information

# %%
df_gaming = df

df_gaming.drop(df_gaming[df_gaming.category_code != "games_video"].index, axis=0, inplace=True)

# %%
df_gaming.dropna(subset = ['offices.city'])
df_gaming.shape
# Out:
# (956, 12)

# %% [markdown]
# ## Result: New York

# %%
df_gaming["offices.city"].value_counts()
# Out:
# New York         75
# San Francisco    68
#                  54
# London           36
# Los Angeles      31
#                  ..
# Boothwyn          1
# Goteborg AB       1
# Los Angleles      1
# Fairfield         1
# Cesena            1
# Name: offices.city, Length: 363, dtype: int64

# %% [markdown]
# ## Designers requirement: City with design companies

# %% [markdown]
# Search for cities with design companies, because this will be one of our requirements for the new office.

# %%
df = pd.DataFrame(json_normalize(a))
print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
# (16705, 12)
#                         _id       name    category_code offices.description  \
# 0  52cdef7c4bab8bd675297d8a   Wetpaint              web
# 1  52cdef7c4bab8bd675297d8a   Wetpaint              web
# 2  52cdef7c4bab8bd675297d8b  AdventNet       enterprise        Headquarters
# 3  52cdef7c4bab8bd675297d8c       Zoho         software        Headquarters
# 4  52cdef7c4bab8bd675297d8f  Omnidrive  network_hosting
#
#        offices.address1 offices.address2 offices.zip_code offices.city  \
# 0      710 - 2nd Avenue       Suite 1100            98104      Seattle
# 1  270 Lafayette Street        Suite 505            10012     New York
# 2      4900 Hopyard Rd.        Suite 310            94588   Pleasanton
# 3       4900 Hopyard Rd        Suite 310            94588   Pleasanton
# 4             Suite 200  654 High Street            94301    Palo Alto
#
#   offices.state_code offices.country_code  offices.latitude  offices.longitude
# 0                 WA                  USA         47.603122        -122.333253
# 1                 NY                  USA         40.723731         -73.996431
# 2                 CA                  USA         37.692934        -121.904945
# 3                 CA                  USA         37.692934        -121.904945
# 4                 CA                  ISR               NaN                NaN

# %% [markdown]
# ## Filter only Category Design/Web that has the city information

# %%
df_design = df

df_design.drop(df_design[(df_design['category_code'] != "web") & (df_design['category_code'] != "design")].index , inplace=True)

# %%
print(df_design.shape)
df_design.head()
# Out:
# (3085, 12)
#                         _id      name category_code offices.description  \
# 0  52cdef7c4bab8bd675297d8a  Wetpaint           web
# 1  52cdef7c4bab8bd675297d8a  Wetpaint           web
# 5  52cdef7c4bab8bd675297d90   Postini           web                None
# 6  52cdef7c4bab8bd675297d91      Geni           web        Headquarters
# 7  52cdef7c4bab8bd675297d96    Gizmoz           web                None
#
#              offices.address1 offices.address2 offices.zip_code  \
# 0            710 - 2nd Avenue       Suite 1100            98104
# 1        270 Lafayette Street        Suite 505            10012
# 5  959 Skyway Road, Suite 200             None            94070
# 6        9229 W. Sunset Blvd.                             90069
# 7                        None             None             None
#
#      offices.city offices.state_code offices.country_code  offices.latitude  \
# 0         Seattle                 WA                  USA         47.603122
# 1        New York                 NY                  USA         40.723731
# 5      San Carlos                 CA                  USA         37.506885
# 6  West Hollywood                 CA                  USA         34.090368
# 7      Menlo Park                 CA                  USA         37.484130
#
#    offices.longitude
# 0        -122.333253
# 1         -73.996431
# 5        -122.247573
# 6        -118.393064
# 7        -122.169472

# %%
df_design.dropna(subset = ['offices.city'])
df_design.shape
# Out:
# (3085, 12)

# %% [markdown]
# ## Result: New York is the second city with more design companies

# %%
df_design["offices.city"].value_counts()
# Out:
# San Francisco        217
# New York             193
#                      184
# London               113
# Seattle               63
#                     ...
# North Miami Beach      1
# Burbank                1
# Chippendale            1
# San Josetje            1
# Singer Island          1
# Name: offices.city, Length: 900, dtype: int64

# %% [markdown]
# Now that we already have New York as our city, due to their number of gaming and design companies, we need to continue to investigate in which coordinate we will launch the new office.

# %% [markdown]
# # First Requirement: Nearby Design companies

# %% [markdown]
# Designers like to go to design talks and share knowledge. There must be some nearby companies that also do design.
#
# Designers represents 23% of the total employees of the company.
#
# Filter all the DESIGN COMPANIES COORDINATES IN NEW YORK. Our new office needs to be nearby these range of coordinates.

# %%
ny_offices = list(db.companies.find({"offices.city":{"$eq":"New York"}},{"offices":1,"name":1,"category_code":1}))

# %%
data = pd.DataFrame(ny_offices) 
data.shape
# Out:
# (832, 4)

# %%
data = data.explode("offices")
data.head()
# Out:
#                         _id      name category_code  \
# 0  52cdef7c4bab8bd675297d8a  Wetpaint           web
# 0  52cdef7c4bab8bd675297d8a  Wetpaint           web
# 1  52cdef7c4bab8bd675297d9d     Joost   games_video
# 2  52cdef7c4bab8bd675297d9f    Viacom           web
# 3  52cdef7c4bab8bd675297da7   AddThis   advertising
#
#                                              offices
# 0  {'description': '', 'address1': '710 - 2nd Ave...
# 0  {'description': '', 'address1': '270 Lafayette...
# 1  {'description': '', 'address1': '100 5th Ave F...
# 2  {'description': 'HQ', 'address1': '1515 Broadw...
# 3  {'description': 'HQ - Virginia', 'address1': '...

# %%
def officeToGeoPoint(row):
    office = row.offices
    if type(office) == dict:
        if 'latitude' in office and 'longitude' in office:
            if(type(office["latitude"])) == float and type(office["longitude"]) == float:
                return ({
                    "type":"Point",
                    "coordinates":[office["longitude"],office["latitude"]]
                },"success")
            else:
                return(None,"Invalid lat lat and long")
        else:
            return (None,"No lat and long keys in office dict")
    return (None,"No office")

# %%
cleaned_data = data.apply(officeToGeoPoint,axis=1, result_type="expand")
cleaned_data.columns = ["office","clean_state"]

cleaned_data.head()
# Out:
#                                               office clean_state
# 0  {'type': 'Point', 'coordinates': [-122.333253,...     success
# 0  {'type': 'Point', 'coordinates': [-73.9964312,...     success
# 1  {'type': 'Point', 'coordinates': [-74.0094471,...     success
# 2  {'type': 'Point', 'coordinates': [-73.986011, ...     success
# 3  {'type': 'Point', 'coordinates': [-77.245195, ...     success

# %%
data_processed = pd.concat([data,cleaned_data], axis=1)

# %%
data_processed = data_processed[["name","category_code","office","clean_state"]]

# %% [markdown]
# ## Filter only companies with coordinates

# %%
data_processed = data_processed[data_processed.clean_state == 'success']
data_processed.head()
# Out:
#        name category_code                                             office  \
# 0  Wetpaint           web  {'type': 'Point', 'coordinates': [-122.333253,...
# 0  Wetpaint           web  {'type': 'Point', 'coordinates': [-73.9964312,...
# 1     Joost   games_video  {'type': 'Point', 'coordinates': [-74.0094471,...
# 2    Viacom           web  {'type': 'Point', 'coordinates': [-73.986011, ...
# 3   AddThis   advertising  {'type': 'Point', 'coordinates': [-77.245195, ...
#
#   clean_state
# 0     success
# 0     success
# 1     success
# 2     success
# 3     success

# %% [markdown]
# ## Filter only Design/Web companies

# %%
data_final = data_processed[data_processed.category_code == 'web']
data_final.head()
# Out:
#         name category_code                                             office  \
# 0   Wetpaint           web  {'type': 'Point', 'coordinates': [-122.333253,...
# 0   Wetpaint           web  {'type': 'Point', 'coordinates': [-73.9964312,...
# 2     Viacom           web  {'type': 'Point', 'coordinates': [-73.986011, ...
# 5     Meetup           web  {'type': 'Point', 'coordinates': [-73.995722, ...
# 12     Meebo           web  {'type': 'Point', 'coordinates': [-122.079017,...
#
#    clean_state
# 0      success
# 0      success
# 2      success
# 5      success
# 12     success

# %%
data_final.shape
# Out:
# (179, 4)

# %% [markdown]
# We have a range of 179 coordinates in New York to use as a reference to search for the new office.

# %% [markdown]
# ## Convert into Json

# %%
data_final.to_json("../Input/data_final.json",orient="records")

# %% [markdown]
# ## Get the point of reference of data_final file:

# %%
data_mean = list(db.data_prepared.aggregate([{"$unwind":"$office"},{"$project":{"office":1,"name":1,"category_code":1}}]))

# %%
data_mean = pd.DataFrame(json_normalize(data_mean))
data_mean
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                           _id             name category_code office.type  \
# 0    5e9c487168b89a1cb3809e1e           Meetup           web       Point
# 1    5e9c487168b89a1cb3809e1f            Meebo           web       Point
# 2    5e9c487168b89a1cb3809e20      Buzzmetrics           web       Point
# 3    5e9c487168b89a1cb3809e21            Heavy           web       Point
# 4    5e9c487168b89a1cb3809e22           Viacom           web       Point
# ..                        ...              ...           ...         ...
# 174  5e9c487168b89a1cb3809ecc  Strategist News           web       Point
# 175  5e9c487168b89a1cb3809ecd           Zemoga           web       Point
# 176  5e9c487168b89a1cb3809ece           Zemoga           web       Point
# 177  5e9c487168b89a1cb3809ecf    ChallengePost           web       Point
# 178  5e9c487168b89a1cb3809ed0       FledgeWing           web       Point
#
#             office.coordinates
# 0       [-73.995722, 40.72604]
# 1     [-122.079017, 37.393679]
# 2      [-73.991933, 40.731118]
# 3       [-73.98962, 40.753385]
# 4      [-73.986011, 40.757725]
# ..                         ...
# 174  [-73.9918181, 40.7489381]
# 175    [-73.989947, 40.744697]
# 176  [-73.4313029, 41.1932851]
# 177    [-74.00717, 40.7408042]
# 178  [-73.9874105, 40.7322535]
#
# [179 rows x 5 columns]

# %%
data_mean.describe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1653, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
#                              _id      name category_code office.type  \
# count                        179       179           179         179
# unique                       179       154             1           1
# top     5e9c487168b89a1cb3809ea1  Allopass           web       Point
# freq                           1         4           179         179
#
#              office.coordinates
# count                       179
# unique                      151
# top     [-73.985506, 40.757929]
# freq                          6

# %% [markdown]
# ## Point of reference:
#
# Coordinates: [-73.985506, 40.757929]
#
# Address: 159 West 45th Street, New York, NY 10036*
#
# *We have searched for the address on the internet though the coordinates.

# %% [markdown]
# # Filtering the coordinates based on the requirements

# %% [markdown]
# ## Geocoding

# %% [markdown]
# Gives the coordinates from an address.

# %%
def geocode(address):
    res = requests.get(f"https://geocode.xyz/{address}",params={"json":1})
    data = res.json()
    print(res)
    return {
    "type": "Point",
    "coordinates": [float(data["longt"]), float(data["latt"])]
  }

# %% [markdown]
# ## Query Nearby

# %% [markdown]
# Filter the coordinates that are in the requested radius from a specific point of reference.

# %%
def getOfficeNear(address, maxDist=1000):
    point = geocode(address)
    return {
       "office": {
         "$near": {
           "$geometry": point,
           "$maxDistance": maxDist,
         }
       } 
    }

# %% [markdown]
# ## Using our Point of reference

# %%
query = getOfficeNear("159 West 45th Street, New York, NY 10036")
query
# Out:
# <Response [200]>
# {'office': {'$near': {'$geometry': {'type': 'Point',
#     'coordinates': [-73.98439, 40.75748]},
#    '$maxDistance': 1000}}}

# %% [markdown]
# ## Result:
#
# From our point of reference (-73.985506, 40.757929), we have 32 design companies in a 1KM radius. This fulfill one of the requirements.

# %%
cur = db.data_prepared.find(query, {"_id":0})
print(cur.count())
result = list(cur)
result
# Out:
# 32
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
# [{'name': 'Tacoda',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Totspot',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Kidmondo',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'SnapVillage',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Blog Talk Radio',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Gamers Media',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Viacom',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986011, 40.757725]},
#   'clean_state': 'success'},
#  {'name': 'Giant Realm',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.9827553, 40.7566658]},
#   'clean_state': 'success'},
#  {'name': 'Livekick',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Healism',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Udorse',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Wee Web',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'People Capital',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Dragonfly',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'CPXi',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.9869523, 40.7550708]},
#   'clean_state': 'success'},
#  {'name': 'yoonew',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986557, 40.75362]},
#   'clean_state': 'success'},
#  {'name': 'Odeo',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.981237, 40.753918]},
#   'clean_state': 'success'},
#  {'name': 'Behind the Burner',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.981237, 40.753918]},
#   'clean_state': 'success'},
#  {'name': 'Cellfish',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.983754, 40.761855]},
#   'clean_state': 'success'},
#  {'name': 'Springo',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.978432, 40.758062]},
#   'clean_state': 'success'},
#  {'name': 'Veotag',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.98546, 40.752957]},
#   'clean_state': 'success'},
#  {'name': 'LineUpNewYork',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986771, 40.753202]},
#   'clean_state': 'success'},
#  {'name': 'BountyJobs',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.97917, 40.754211]},
#   'clean_state': 'success'},
#  {'name': 'TheMarkets',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.9821315, 40.762674]},
#   'clean_state': 'success'},
#  {'name': 'Heavy',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.98962, 40.753385]},
#   'clean_state': 'success'},
#  {'name': 'Oddcast',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.988477, 40.752325]},
#   'clean_state': 'success'},
#  {'name': 'Facilitas',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.991123, 40.753931]},
#   'clean_state': 'success'},
#  {'name': 'Xanga',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.992152, 40.754698]},
#   'clean_state': 'success'},
#  {'name': 'Flugpo',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.990557, 40.752898]},
#   'clean_state': 'success'},
#  {'name': 'Kiwibox',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.9935, 40.755243]},
#   'clean_state': 'success'},
#  {'name': 'Social Median',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.982575, 40.74963]},
#   'clean_state': 'success'},
#  {'name': 'acerno',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.975857, 40.751363]},
#   'clean_state': 'success'}]

# %% [markdown]
# ## Get the final coordinates

# %%
def easyLatLng(row):
    of = row.office
    return {
        "latitude":of["coordinates"][1],
        "longitude":of["coordinates"][0]
    }

# https://api.mongodb.com/python/current/api/bson/objectid.html
df = pd.DataFrame(result)

df = pd.concat([df, df.apply(easyLatLng, axis=1, result_type="expand")], axis=1)
df
# Out:
#                  name category_code  \
# 0              Tacoda           web
# 1             Totspot           web
# 2            Kidmondo           web
# 3         SnapVillage           web
# 4     Blog Talk Radio           web
# 5        Gamers Media           web
# 6              Viacom           web
# 7         Giant Realm           web
# 8            Livekick           web
# 9             Healism           web
# 10             Udorse           web
# 11            Wee Web           web
# 12     People Capital           web
# 13          Dragonfly           web
# 14               CPXi           web
# 15             yoonew           web
# 16               Odeo           web
# 17  Behind the Burner           web
# 18           Cellfish           web
# 19            Springo           web
# 20             Veotag           web
# 21      LineUpNewYork           web
# 22         BountyJobs           web
# 23         TheMarkets           web
# 24              Heavy           web
# 25            Oddcast           web
# 26          Facilitas           web
# 27              Xanga           web
# 28             Flugpo           web
# 29            Kiwibox           web
# 30      Social Median           web
# 31             acerno           web
#
#                                                office clean_state   latitude  \
# 0   {'type': 'Point', 'coordinates': [-73.985506, ...     success  40.757929
# 1   {'type': 'Point', 'coordinates': [-73.985506, ...     success  40.757929
# 2   {'type': 'Point', 'coordinates': [-73.985506, ...     success  40.757929
# 3   {'type': 'Point', 'coordinates': [-73.985506, ...     success  40.757929
# 4   {'type': 'Point', 'coordinates': [-73.985506, ...     success  40.757929
# 5   {'type': 'Point', 'coordinates': [-73.985506, ...     success  40.757929
# 6   {'type': 'Point', 'coordinates': [-73.986011, ...     success  40.757725
# 7   {'type': 'Point', 'coordinates': [-73.9827553,...     success  40.756666
# 8   {'type': 'Point', 'coordinates': [-73.986951, ...     success  40.756054
# 9   {'type': 'Point', 'coordinates': [-73.986951, ...     success  40.756054
# 10  {'type': 'Point', 'coordinates': [-73.986951, ...     success  40.756054
# 11  {'type': 'Point', 'coordinates': [-73.986951, ...     success  40.756054
# 12  {'type': 'Point', 'coordinates': [-73.986951, ...     success  40.756054
# 13  {'type': 'Point', 'coordinates': [-73.986951, ...     success  40.756054
# 14  {'type': 'Point', 'coordinates': [-73.9869523,...     success  40.755071
# 15  {'type': 'Point', 'coordinates': [-73.986557, ...     success  40.753620
# 16  {'type': 'Point', 'coordinates': [-73.981237, ...     success  40.753918
# 17  {'type': 'Point', 'coordinates': [-73.981237, ...     success  40.753918
# 18  {'type': 'Point', 'coordinates': [-73.983754, ...     success  40.761855
# 19  {'type': 'Point', 'coordinates': [-73.978432, ...     success  40.758062
# 20  {'type': 'Point', 'coordinates': [-73.98546, 4...     success  40.752957
# 21  {'type': 'Point', 'coordinates': [-73.986771, ...     success  40.753202
# 22  {'type': 'Point', 'coordinates': [-73.97917, 4...     success  40.754211
# 23  {'type': 'Point', 'coordinates': [-73.9821315,...     success  40.762674
# 24  {'type': 'Point', 'coordinates': [-73.98962, 4...     success  40.753385
# 25  {'type': 'Point', 'coordinates': [-73.988477, ...     success  40.752325
# 26  {'type': 'Point', 'coordinates': [-73.991123, ...     success  40.753931
# 27  {'type': 'Point', 'coordinates': [-73.992152, ...     success  40.754698
# 28  {'type': 'Point', 'coordinates': [-73.990557, ...     success  40.752898
# 29  {'type': 'Point', 'coordinates': [-73.9935, 40...     success  40.755243
# 30  {'type': 'Point', 'coordinates': [-73.982575, ...     success  40.749630
# 31  {'type': 'Point', 'coordinates': [-73.975857, ...     success  40.751363
#
#     longitude
# 0  -73.985506
# 1  -73.985506
# 2  -73.985506
# 3  -73.985506
# 4  -73.985506
# 5  -73.985506
# 6  -73.986011
# 7  -73.982755
# 8  -73.986951
# 9  -73.986951
# 10 -73.986951
# 11 -73.986951
# 12 -73.986951
# 13 -73.986951
# 14 -73.986952
# 15 -73.986557
# 16 -73.981237
# 17 -73.981237
# 18 -73.983754
# 19 -73.978432
# 20 -73.985460
# 21 -73.986771
# 22 -73.979170
# 23 -73.982131
# 24 -73.989620
# 25 -73.988477
# 26 -73.991123
# 27 -73.992152
# 28 -73.990557
# 29 -73.993500
# 30 -73.982575
# 31 -73.975857
